# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

#Máscaras.
sobel_x = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
sobel_y = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
roberts_xy = np.array([[1, 0], [0, -1]])
roberts_yx = np.array([[0, 1], [-1, 0]])
laplace = np.array([[0, 1, 0], [1, -4, 1], [0, 1, 0]])

# %% [markdown]
# 1) Aplique os filtros de realce Sobel e Roberts nas imagens abaixo. Mostre, para o caso do Sobel, uma imagem representando a derivada em x e outra imagem representando a derivada em y.

# %%
#Aplicação do filtro Gaussiano para remoção de ruídos, o que facilita a identificação das bordas.
img1 = cv2.GaussianBlur(cv2.imread("cln1.png", cv2.IMREAD_GRAYSCALE),(3,3),0)

#Convolução. 
img1_sobel_x = cv2.filter2D(img1, -1, sobel_x)
img1_sobel_y = cv2.filter2D(img1, -1, sobel_y)

img1_roberts_xy = cv2.filter2D(img1, -1, roberts_xy)
img1_roberts_yx = cv2.filter2D(img1, -1, roberts_yx)

fig = plt.figure(figsize=(15, 45))
rows = 1
columns = 4

fig.add_subplot(rows, columns, 1)
plt.imshow(img1_sobel_x, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Sobel X")

fig.add_subplot(rows, columns, 2)
plt.imshow(img1_sobel_y, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Sobel Y")

fig.add_subplot(rows, columns, 3)
plt.imshow(img1_roberts_xy, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Roberts XY")

fig.add_subplot(rows, columns, 4)
plt.imshow(img1_roberts_yx, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Roberts YX")
# Out:
# Text(0.5, 1.0, 'Roberts YX')

# %% [markdown]
# 2) Utilizando a mesma imagem, realce as bordas utilizando (a) Filtro Laplaciano, (b) Unsharp masking, (c) Highboost filtering (escolher um k) e (d) K <1 para atenuar.

# %%
img1_laplace = cv2.filter2D(img1, -1, laplace)

img1_um = img1 - img1_laplace
img1_hf_a = img1 - 2 * img1_laplace
img1_hf_b = img1 - 0.5 * img1_laplace

fig = plt.figure(figsize=(15, 45))
rows = 1
columns = 4

fig.add_subplot(rows, columns, 1)
plt.imshow(img1_laplace, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Laplace")

fig.add_subplot(rows, columns, 2)
plt.imshow(img1_um, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Unsharp Masking")

fig.add_subplot(rows, columns, 3)
plt.imshow(img1_hf_a, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Highboost Filtering (k = 2)")

fig.add_subplot(rows, columns, 4)
plt.imshow(img1_hf_b, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Highboost Filtering (k = 0.5)")
# Out:
# Text(0.5, 1.0, 'Highboost Filtering (k = 0.5)')

# %% [markdown]
# 3) Aplique o operador Sobel imagem original abaixo e obtenha as outras imagens conforme descrição:
# "We can see that the intensity of many pixels on the surface is as high as along the actual edges. One reason is that the output of many edge pixels is greater than the maximum pixel value and therefore they are `cut off' at 255. To avoid this overflow we scale the range image by a factor 0.25 prior to the edge detection and then normalize the output, as can be seen in (c)"

# %%
img2 = cv2.imread("ren1.png", cv2.IMREAD_GRAYSCALE)
img2_sobel_x = cv2.filter2D(img2, -1, sobel_x)
#img2_final = ??? (Fazer o que é dito na descrição em inglês). Ver o resultado nesse link: https://homepages.inf.ed.ac.uk/rbf/HIPR2/sobel.htm

fig = plt.figure(figsize=(15, 45))
rows = 1
columns = 2     #Trocar para 3 ao encerrar a tarefa.

fig.add_subplot(rows, columns, 1)
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Original")

fig.add_subplot(rows, columns, 2)
plt.imshow(img2_sobel_x, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Sobel X")

"""
fig.add_subplot(rows, columns, 3)
plt.imshow(img2_final, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.title("Final")
"""
# Out:
# Text(0.5, 1.0, 'Sobel X')

# %% [markdown]
# 4) Aplique o operador Sobel nas imagens abaixo e obtenha a imagem binária após a limiarização utilizando o valor 150.
# 5) Repita, com a outra imagem.

# %%
#4. Usamos Sobel X nesse.
img3 = cv2.imread("ufo2.png", cv2.IMREAD_GRAYSCALE)
img3_sobel_x = cv2.filter2D(img3, -1, sobel_x)
#img3_final = ??? (Fazer a Limiarização)

#5. Usamos Sobel Y no outro.
img4 = cv2.imread("ufo2noi2.png", cv2.IMREAD_GRAYSCALE)
img4_sobel_y = cv2.filter2D(img4, -1, sobel_x)
#img4_final = ??? (Fazer a Limiarização)
